# %% [markdown]
# # Creating Epistemic Plots from Runs

# %% [markdown]
# Going to move code in both `experiments/CIFAR-10/eval/analyze_experiments.py` and `
# `experiments/CIFAR-10/eval/epistemic_analysis.py`
